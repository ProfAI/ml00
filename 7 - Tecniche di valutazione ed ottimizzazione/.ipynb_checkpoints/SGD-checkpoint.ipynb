# %% [markdown]
# # Stochastic, Mini Batch e Full Batch Gradient Descend
# In questo notebook eseguiremo una classificazione utilizzando Full Batch Gradient Descend, Stochastic Gradient Descend e Mini Batch Gradient Descend al fine di confrontare le oscillazioni della funzione di costo per ognuno di essi.<br>
# Importiamo le librerie necessarie

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
from sklearn.metrics import log_loss

# %% [markdown]
# Ed utilizziamo la funzione *make_classification* di scikit-learn per creare un dataset ad-hoc in cui poter eseguire la nostra classificazione

# %%
X, Y = make_classification(n_samples=1250, n_features=4, n_informative=2, random_state=0)
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Stochastic Gradient Descend

# %% [markdown]
# Lo Stochastic Gradient Descend (SGD) è versione del Gradient Descend che utilizza un solo esempio di addestramento per volta.<br>
# Possiamo utilizzare la classe SGDClassifier di scikit-learn, di default questa utilizza lo SGD per addestrare una SVM, ma possiamo modificare la tipologia di modello semplicemente cambiando la funzione di costo:
#
#  * **hinge**: l'SGD addestrerà una SVM
#  * **log**: l'SGD addestrerà una regressione logistica
#  * **perceptron:** l'SGD addestrerà un percettrone
#
# Per evitare cicli bisogna mischiare il train set ad ogni epoca, per farlo basta impostare il parametro shuffle a True (questo valore è settato di default, quindi è possibile anche ometterlo)<br>
# **NOTA BENE** Lo Stochastic Gradient Descend è un processo stocastico (ma vah), anche utilizzando gli stessi iperparametri un modello fornirà risultati lievemente se riaddestrato.

# %%
# %%time
from sklearn.linear_model import SGDClassifier
sgd = SGDClassifier(loss="log", verbose=False, shuffle=True) #verbose ci mostrerà informazioni sull'avanzamento dell'addestramento<
sgd.fit(X_train,Y_train)
print("LOSS: %.4f" % (log_loss(Y_test, sgd.predict_proba(X_test))))
# Out:
# LOSS: 0.2254
# CPU times: user 3.4 ms, sys: 1.5 ms, total: 4.9 ms
# Wall time: 3.32 ms
# /Users/giuseppe/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %% [markdown]
# La classe SGDClassifier ci mette a disposizione il metodo partial_fit, che ci permette di eseguire l'addestramento su una parte di dati definita da noi.<br>
# Utilizziamo *partial_fit* per eseguire lo stochastic gradient descend e raccogliamo il valore della funzione di costo ad ogni iterazione.<br>
# **NOTA BENE** se utilizziamo partial_fit dobbiamo mischiare i dati manualmente ad ogni epoca, per farlo possiamo utilizzare il metodo shuffle di sklearn.

# %%
# %%time
from sklearn.utils import shuffle

epochs = 5

n_batches=X_train.shape[0]
batch_size = X_train.shape[0]/n_batches

classes = np.unique(Y_train)

sgd = SGDClassifier(loss="log")
sgd_losses = []

for epoch in range(epochs):
        X_shuffled, Y_shuffled = shuffle(X_train, Y_train)
        for batch in range(n_batches):
            batch_start = int(batch*batch_size)
            batch_end = int((batch+1)*batch_size)
            X_batch = X_shuffled[batch_start:batch_end,:]
            Y_batch = Y_shuffled[batch_start:batch_end]

            sgd.partial_fit(X_batch, Y_batch, classes=classes)
            loss = log_loss(Y_test, sgd.predict_proba(X_test),labels=classes)
            sgd_losses.append(loss)       
        print("Loss all'epoca %d = %.4f" % (epoch+1, loss))
# Out:
# /Users/giuseppe/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# Loss all'epoca 1 = 0.4975
# Loss all'epoca 2 = 0.3625
# Loss all'epoca 3 = 0.2073
# Loss all'epoca 4 = 0.2827
# Loss all'epoca 5 = 0.1766
# CPU times: user 3.95 s, sys: 22 ms, total: 3.98 s
# Wall time: 3.97 s

# %% [markdown]
# I risultati non sono buoni perché il numero di epoche definito non è sufficente per far convergere il gradient descend e quindi per trovare i coefficenti ottimali del modello<br>
# Visualizzaziamo il grafico della funzione di costo ad ogni iterazione.

# %%
plt.figure(figsize=(14,10))
plt.title("Stochastic Gradient Descend")
plt.xlabel("Iterazione")
plt.ylabel("Log-Loss")
plt.plot(sgd_losses)

# %% [markdown]
# Il graico della funzione di costo per iterazione presenta un notevole rumore.

# %% [markdown]
# ## Full Batch Gradient Descend
# Adesso eseguiamo un Full Batch Gradient Descend sempre utilizzando la funzione partial_fit, per farlo è sufficente passare l'intero train set ad ogni iterazione.

# %%
# %%time

epochs = 200

n_batches=1

batch_size = X_train.shape[0]/n_batches

classes = np.unique(Y)

sgd = SGDClassifier(loss="log")
full_losses = []

for epoch in range(epochs):
        loss = 0.
        X_shuffled, Y_shuffled = shuffle(X_train, Y_train)
        for batch in range(n_batches):
            batch_start = int(batch*batch_size)
            batch_end = int((batch+1)*batch_size)
            X_batch = X_shuffled[batch_start:batch_end,:]
            Y_batch = Y_shuffled[batch_start:batch_end]

            sgd.partial_fit(X_batch, Y_batch, classes=classes)
            loss = log_loss(Y_test, sgd.predict_proba(X_test),labels=classes)
            full_losses.append(loss)       
        print("Loss all'epoca %d = %.4f" % (epoch+1, loss))
# Out:
# /Users/giuseppe/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# Loss all'epoca 1 = 0.6394
# Loss all'epoca 2 = 0.5632
# Loss all'epoca 3 = 0.4506
# Loss all'epoca 4 = 0.3343
# Loss all'epoca 5 = 0.1902
# Loss all'epoca 6 = 0.1991
# Loss all'epoca 7 = 0.2325
# Loss all'epoca 8 = 0.1290
# Loss all'epoca 9 = 0.1949
# Loss all'epoca 10 = 0.1714
# Loss all'epoca 11 = 0.1133
# Loss all'epoca 12 = 0.1368
# Loss all'epoca 13 = 0.1511
# Loss all'epoca 14 = 0.1205
# Loss all'epoca 15 = 0.1135
# Loss all'epoca 16 = 0.1599
# Loss all'epoca 17 = 0.1229
# Loss all'epoca 18 = 0.1645
# Loss all'epoca 19 = 0.1383
# Loss all'epoca 20 = 0.1176
# Loss all'epoca 21 = 0.1189
# Loss all'epoca 22 = 0.1297
# Loss all'epoca 23 = 0.1106
# Loss all'epoca 24 = 0.1277
# Loss all'epoca 25 = 0.1381
# Loss all'epoca 26 = 0.1256
# Loss all'epoca 27 = 0.1186
# Loss all'epoca 28 = 0.1441
# Loss all'epoca 29 = 0.1205
# Loss all'epoca 30 = 0.1115
# Loss all'epoca 31 = 0.1104
# Loss all'epoca 32 = 0.1071
# Loss all'epoca 33 = 0.1142
# Loss all'epoca 34 = 0.1108
# Loss all'epoca 35 = 0.1247
# Loss all'epoca 36 = 0.1214
# Loss all'epoca 37 = 0.1147
# Loss all'epoca 38 = 0.1156
# Loss all'epoca 39 = 0.1195
# Loss all'epoca 40 = 0.1099
# Loss all'epoca 41 = 0.1142
# Loss all'epoca 42 = 0.1202
# Loss all'epoca 43 = 0.1072
# Loss all'epoca 44 = 0.1149
# Loss all'epoca 45 = 0.1081
# Loss all'epoca 46 = 0.1081
# Loss all'epoca 47 = 0.1170
# Loss all'epoca 48 = 0.1140
# Loss all'epoca 49 = 0.1095
# Loss all'epoca 50 = 0.1165
# Loss all'epoca 51 = 0.1064
# Loss all'epoca 52 = 0.1118
# Loss all'epoca 53 = 0.1077
# Loss all'epoca 54 = 0.1165
# Loss all'epoca 55 = 0.1134
# Loss all'epoca 56 = 0.1120
# Loss all'epoca 57 = 0.1060
# Loss all'epoca 58 = 0.1183
# Loss all'epoca 59 = 0.1093
# Loss all'epoca 60 = 0.1066
# Loss all'epoca 61 = 0.1072
# Loss all'epoca 62 = 0.1059
# Loss all'epoca 63 = 0.1098
# Loss all'epoca 64 = 0.1064
# Loss all'epoca 65 = 0.1111
# Loss all'epoca 66 = 0.1071
# Loss all'epoca 67 = 0.1186
# Loss all'epoca 68 = 0.1101
# Loss all'epoca 69 = 0.1091
# Loss all'epoca 70 = 0.1155
# Loss all'epoca 71 = 0.1127
# Loss all'epoca 72 = 0.1189
# Loss all'epoca 73 = 0.1110
# Loss all'epoca 74 = 0.1092
# Loss all'epoca 75 = 0.1060
# Loss all'epoca 76 = 0.1140
# Loss all'epoca 77 = 0.1075
# Loss all'epoca 78 = 0.1101
# Loss all'epoca 79 = 0.1061
# Loss all'epoca 80 = 0.1060
# Loss all'epoca 81 = 0.1078
# Loss all'epoca 82 = 0.1086
# Loss all'epoca 83 = 0.1081
# Loss all'epoca 84 = 0.1113
# Loss all'epoca 85 = 0.1089
# Loss all'epoca 86 = 0.1154
# Loss all'epoca 87 = 0.1058
# Loss all'epoca 88 = 0.1102
# Loss all'epoca 89 = 0.1079
# Loss all'epoca 90 = 0.1076
# Loss all'epoca 91 = 0.1108
# Loss all'epoca 92 = 0.1072
# Loss all'epoca 93 = 0.1083
# Loss all'epoca 94 = 0.1072
# Loss all'epoca 95 = 0.1070
# Loss all'epoca 96 = 0.1091
# Loss all'epoca 97 = 0.1080
# Loss all'epoca 98 = 0.1112
# Loss all'epoca 99 = 0.1070
# Loss all'epoca 100 = 0.1057
# Loss all'epoca 101 = 0.1066
# Loss all'epoca 102 = 0.1111
# Loss all'epoca 103 = 0.1064
# Loss all'epoca 104 = 0.1053
# Loss all'epoca 105 = 0.1099
# Loss all'epoca 106 = 0.1065
# Loss all'epoca 107 = 0.1112
# Loss all'epoca 108 = 0.1077
# Loss all'epoca 109 = 0.1070
# Loss all'epoca 110 = 0.1106
# Loss all'epoca 111 = 0.1059
# Loss all'epoca 112 = 0.1060
# Loss all'epoca 113 = 0.1070
# Loss all'epoca 114 = 0.1075
# Loss all'epoca 115 = 0.1082
# Loss all'epoca 116 = 0.1081
# Loss all'epoca 117 = 0.1073
# Loss all'epoca 118 = 0.1063
# Loss all'epoca 119 = 0.1070
# Loss all'epoca 120 = 0.1067
# Loss all'epoca 121 = 0.1078
# Loss all'epoca 122 = 0.1084
# Loss all'epoca 123 = 0.1054
# Loss all'epoca 124 = 0.1065
# Loss all'epoca 125 = 0.1075
# Loss all'epoca 126 = 0.1056
# Loss all'epoca 127 = 0.1053
# Loss all'epoca 128 = 0.1065
# Loss all'epoca 129 = 0.1088
# Loss all'epoca 130 = 0.1071
# Loss all'epoca 131 = 0.1122
# Loss all'epoca 132 = 0.1102
# Loss all'epoca 133 = 0.1067
# Loss all'epoca 134 = 0.1071
# Loss all'epoca 135 = 0.1095
# Loss all'epoca 136 = 0.1055
# Loss all'epoca 137 = 0.1058
# Loss all'epoca 138 = 0.1063
# Loss all'epoca 139 = 0.1067
# Loss all'epoca 140 = 0.1057
# Loss all'epoca 141 = 0.1064
# Loss all'epoca 142 = 0.1058
# Loss all'epoca 143 = 0.1082
# Loss all'epoca 144 = 0.1085
# Loss all'epoca 145 = 0.1055
# Loss all'epoca 146 = 0.1070
# Loss all'epoca 147 = 0.1059
# Loss all'epoca 148 = 0.1058
# Loss all'epoca 149 = 0.1072
# Loss all'epoca 150 = 0.1081
# Loss all'epoca 151 = 0.1066
# Loss all'epoca 152 = 0.1056
# Loss all'epoca 153 = 0.1054
# Loss all'epoca 154 = 0.1063
# Loss all'epoca 155 = 0.1066
# Loss all'epoca 156 = 0.1066
# Loss all'epoca 157 = 0.1081
# Loss all'epoca 158 = 0.1059
# Loss all'epoca 159 = 0.1071
# Loss all'epoca 160 = 0.1062
# Loss all'epoca 161 = 0.1065
# Loss all'epoca 162 = 0.1072
# Loss all'epoca 163 = 0.1068
# Loss all'epoca 164 = 0.1067
# Loss all'epoca 165 = 0.1055
# Loss all'epoca 166 = 0.1064
# Loss all'epoca 167 = 0.1058
# Loss all'epoca 168 = 0.1060
# Loss all'epoca 169 = 0.1065
# Loss all'epoca 170 = 0.1068
# Loss all'epoca 171 = 0.1058
# Loss all'epoca 172 = 0.1081
# Loss all'epoca 173 = 0.1070
# Loss all'epoca 174 = 0.1069
# Loss all'epoca 175 = 0.1065
# Loss all'epoca 176 = 0.1065
# Loss all'epoca 177 = 0.1077
# Loss all'epoca 178 = 0.1061
# Loss all'epoca 179 = 0.1056
# Loss all'epoca 180 = 0.1078
# Loss all'epoca 181 = 0.1102
# Loss all'epoca 182 = 0.1077
# Loss all'epoca 183 = 0.1063
# Loss all'epoca 184 = 0.1067
# Loss all'epoca 185 = 0.1065
# Loss all'epoca 186 = 0.1073
# Loss all'epoca 187 = 0.1060
# Loss all'epoca 188 = 0.1062
# Loss all'epoca 189 = 0.1066
# Loss all'epoca 190 = 0.1068
# Loss all'epoca 191 = 0.1082
# Loss all'epoca 192 = 0.1068
# Loss all'epoca 193 = 0.1089
# Loss all'epoca 194 = 0.1075
# Loss all'epoca 195 = 0.1069
# Loss all'epoca 196 = 0.1061
# Loss all'epoca 197 = 0.1066
# Loss all'epoca 198 = 0.1066
# Loss all'epoca 199 = 0.1068
# Loss all'epoca 200 = 0.1074
# CPU times: user 289 ms, sys: 37.9 ms, total: 327 ms
# Wall time: 294 ms

# %% [markdown]
# Il GD è riuscito a convergere fornendo un buon risultato, vediamo il grafico della funzione di costo ad ogni iterazione ( in questo caso un iterazione corrisponde ad un'epoca )

# %%
plt.figure(figsize=(14,10))
plt.title("Gradient Descend")
plt.xlabel("Iterazione")
plt.ylabel("Log-Loss")
plt.plot(full_losses)

# %% [markdown]
# La variazione della funzione di costo è molto più regolare rispetto allo SGD.

# %% [markdown]
# ## Mini Batch Gradient Descend
# Adess eseguiamo un Mini Batch Gradient Descend con 10 batches, cioè considerando che nel train set ci sono 1000 esempi eseguiremo il Gradient Descend uilizzando 100 esempi per volta.

# %%
# %%time

epochs = 50

n_batches=10

batch_size = X_train.shape[0]/n_batches

classes = np.unique(Y)

sgd = SGDClassifier(loss="log")
batch_losses = []

for epoch in range(epochs):
        X_shuffled, Y_shuffled = shuffle(X_train, Y_train)
        for batch in range(n_batches):
            batch_start = int(batch*batch_size)
            batch_end = int((batch+1)*batch_size)
            X_batch = X_shuffled[batch_start:batch_end,:]
            Y_batch = Y_shuffled[batch_start:batch_end]

            sgd.partial_fit(X_batch, Y_batch, classes=classes)
            loss = log_loss(Y_test, sgd.predict_proba(X_test),labels=classes)
            batch_losses.append(loss)       
        print("Loss all'epoca %d = %.4f" % (epoch+1, loss))
# Out:
# /Users/giuseppe/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# Loss all'epoca 1 = 0.8193
# Loss all'epoca 2 = 0.4858
# Loss all'epoca 3 = 0.5431
# Loss all'epoca 4 = 0.5028
# Loss all'epoca 5 = 0.3026
# Loss all'epoca 6 = 0.1622
# Loss all'epoca 7 = 0.3948
# Loss all'epoca 8 = 0.1424
# Loss all'epoca 9 = 0.1579
# Loss all'epoca 10 = 0.4525
# Loss all'epoca 11 = 0.1300
# Loss all'epoca 12 = 0.1304
# Loss all'epoca 13 = 0.1522
# Loss all'epoca 14 = 0.1666
# Loss all'epoca 15 = 0.1354
# Loss all'epoca 16 = 0.1246
# Loss all'epoca 17 = 0.1287
# Loss all'epoca 18 = 0.1224
# Loss all'epoca 19 = 0.1711
# Loss all'epoca 20 = 0.1079
# Loss all'epoca 21 = 0.1239
# Loss all'epoca 22 = 0.1249
# Loss all'epoca 23 = 0.1272
# Loss all'epoca 24 = 0.1173
# Loss all'epoca 25 = 0.1059
# Loss all'epoca 26 = 0.1121
# Loss all'epoca 27 = 0.1140
# Loss all'epoca 28 = 0.1296
# Loss all'epoca 29 = 0.1115
# Loss all'epoca 30 = 0.1204
# Loss all'epoca 31 = 0.1106
# Loss all'epoca 32 = 0.1203
# Loss all'epoca 33 = 0.1066
# Loss all'epoca 34 = 0.1174
# Loss all'epoca 35 = 0.1108
# Loss all'epoca 36 = 0.1123
# Loss all'epoca 37 = 0.1074
# Loss all'epoca 38 = 0.1092
# Loss all'epoca 39 = 0.1256
# Loss all'epoca 40 = 0.1303
# Loss all'epoca 41 = 0.1102
# Loss all'epoca 42 = 0.1062
# Loss all'epoca 43 = 0.1130
# Loss all'epoca 44 = 0.1109
# Loss all'epoca 45 = 0.1151
# Loss all'epoca 46 = 0.1146
# Loss all'epoca 47 = 0.1071
# Loss all'epoca 48 = 0.1084
# Loss all'epoca 49 = 0.1088
# Loss all'epoca 50 = 0.1060
# CPU times: user 438 ms, sys: 20.2 ms, total: 458 ms
# Wall time: 443 ms

# %%
plt.figure(figsize=(14,10))
plt.title("Batch Gradient Descend")
plt.xlabel("Iterazione")
plt.ylabel("Log-Loss")
plt.plot(batch_losses)

# %% [markdown]
# Le oscillazione della funzione di costo per ogni epoca sono inferiori all'SGD ma superiori al Full Batch

# %% [markdown]
# ## Il confronto
# Confrontiamo le oscillazioni della funzione di costo per Full Batch, Stochastic e Mini Batch Gradient Descend, mettendole su di uno stesso grafico

# %%
# %matplotlib inline
plt.figure(figsize=(14,10))
plt.plot(batch_losses, label="Batch")
plt.plot(sgd_losses, label="Stochastic")
plt.plot(full_losses,label="Full")
plt.xlim(xmin=0,xmax=200)
plt.legend()
plt.show()
